# %%
from faker import Faker
import pandas as pd 
import random as rnd 
from datetime import datetime, timedelta
import shutil

# %%
# --- Configuration ---
Faker.seed(42)
fake = Faker()

# %%
student_fullname = "RATSIHOARANA Nomenahitantsoa Amy Andriamalala"

# %%
# --- Fonction erreurs de formatage ---
def apply_format_errors(df, col):
    for i in df.index:
        r = rnd.random()
        val = str(df.at[i, col])
        if r < 0.3:       # 30 % majuscules + espaces
            df.at[i, col] = "  " + val.upper() + "  "
        elif r < 0.5:     # 20 % minuscules
            df.at[i, col] = val.lower()
        # 50 % reste inchangé
    return df

# %%
e
for pid in range(1, 41):  # 40 projets uniques
    start_date = fake.date_between(start_date='-2y', end_date='-1y')
    end_date = fake.date_between(start_date=start_date, end_date='today')
    
    projects.append({
        "projectid": pid,
        "student_fullname": student_fullname,
        "name": fake.catch_phrase(),                 # cohérent + réaliste
        "client": fake.company(),
        "startdate": start_date,
        "enddate": end_date,
        "version": fake.semver(),                    # version cohérente
    })

# Ajout de 20 doublons : même données sauf ID
indices = rnd.sample(range(40), 20)
for i in indices:
    dup = projects[i].copy()
    dup["projectid"] = len(projects) + 1
    projects.append(dup)



df_projects = pd.DataFrame(projects)
df_projects = apply_format_errors(df_projects, "name")
df_projects = apply_format_errors(df_projects, "client")

print(df_projects)
# Out:
#     projectid                               student_fullname            name  \
# 0           1  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      issueforge
# 1           2  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      SquashFlow
# 2           3  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      BUGPULSE
# 3           4  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     TRACKNEST
# 4           5  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       errorgrid
# 5           6  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        FixRadar
# 6           7  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       DebugDock
# 7           8  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     TRACEHIVE
# 8           9  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        PatchBay
# 9          10  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        bugpulse
# 10         11  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        FixRadar
# 11         12  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        BugPulse
# 12         13  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        LogScope
# 13         14  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       debugdock
# 14         15  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      IssueForge
# 15         16  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     ERRORGRID
# 16         17  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        LogScope
# 17         18  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      BUGPULSE
# 18         19  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     DEBUGDOCK
# 19         20  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     TRACEHIVE
# 20         21  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      IssueForge
# 21         22  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     DEBUGDOCK
# 22         23  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      PATCHBAY
# 23         24  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        PatchBay
# 24         25  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       DebugDock
# 25         26  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        BugPulse
# 26         27  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        LogScope
# 27         28  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        BugPulse
# 28         29  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       TraceHive
# 29         30  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     ERRORGRID
# 30         31  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        FixRadar
# 31         32  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       TraceHive
# 32         33  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       DebugDock
# 33         34  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      IssueForge
# 34         35  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        PatchBay
# 35         36  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      FIXRADAR
# 36         37  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      squashflow
# 37         38  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        LogScope
# 38         39  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       tracehive
# 39         40  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        patchbay
# 40         37  RATSIHOARANA Nomenahitantsoa Amy Andriamalala    SQUASHFLOW
# 41         15  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      IssueForge
# 42         20  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       TraceHive
# 43          3  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        BugPulse
# 44         26  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        bugpulse
# 45          2  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      squashflow
# 46          1  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      issueforge
# 47         14  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       DebugDock
# 48         18  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        BugPulse
# 49         22  RATSIHOARANA Nomenahitantsoa Amy Andriamalala     DEBUGDOCK
# 50         31  RATSIHOARANA Nomenahitantsoa Amy Andriamalala        FixRadar
# 51         30  RATSIHOARANA Nomenahitantsoa Amy Andriamalala       errorgrid
# 52         10  RATSIHOARANA Nomenahitantsoa Amy Andriamalala      BUGPULSE
# 53         13  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 36                      KOCH-DECKER    2024-03-05  2024-04-14   5.6.8
# 37                          Brown PLC  2024-08-04  2025-05-25   2.7.5
# 38                       DENNIS INC    2024-02-09  2024-08-31   1.2.6
# 39       Cannon, Anderson and Alvarez  2025-07-22  2025-08-26   4.8.4
# 40                        Koch-Decker  2024-03-05  2024-04-14   5.6.8
# 41                        james group  2024-06-07  2024-12-18   2.3.8
# 42        ROBINSON, NGUYEN AND TATE    2025-05-27  2026-02-15   1.0.2
# 43    MCCLAIN, MILLER AND HENDERSON    2025-05-18  2025-11-30   1.7.6
# 44                  ROBINSON-BRIGHT    2024-10-15  2025-05-01   5.9.9
# 45                         Taylor Inc  2024-06-17  2025-05-10   1.7.8
# 46                        johnson llc  2025-04-19  2026-03-09   4.2.4
# 47        PEREZ, ROBERTS AND MILLER    2024-01-14  2024-09-08   5.5.2
# 48       REID, FERGUSON AND SANCHEZ    2024-02-03  2024-05-26   0.7.6
# 49                     JONES-GENTRY    2024-10-16  2024-11-19   0.4.7
# 50          Le, Maldonado and Herrera  2023-12-18  2024-06-14   5.7.8
# 51                    Maddox-Valencia  2025-01-23  2025-03-05   3.6.7
# 52                        Munoz-Roman  2024-09-13  2025-07-12   2.6.2
# 53                         RAY-BUSH    2025-04-03  2026-02-14   0.6.1
# 54           Brown, James and Ferrell  2024-11-01  2025-01-15   0.8.8
# 55                     Herrera-Dudley  2025-06-28  2025-12-02   4.8.8
# 56          Sellers, George and Burns  2025-01-31  2025-03-27   5.2.6
# 57                     Davis-Williams  2025-01-08  2025-09-28   0.2.6
# 58                     blake and sons  2025-08-29  2025-10-14   4.5.3
# 59          Baker, Richards and Hurst  2025-02-18  2025-07-03   5.4.3

# %%
# --- TABLE DEVELOPER ---
specialties = ["Frontend", "Backend", "Fullstack", "DevOps", "QA", "Security"]
developers = []

for devid in range(40):
    name = fake.name()
    name_parts = name.lower().replace(".", "").replace("'", "").split()
    email = f"{'.'.join(name_parts)}@gmail.com"
    specialty = rnd.choice(specialties)
    developers.append({
        "devid": devid + 1,
        "student_fullname": student_fullname,
        "name": name,
        "email": email,
        "specialty": specialty
    })

original_indices = rnd.sample(range(40), 20)
for i in original_indices:
    duplicate = developers[i].copy()
    developers.append(duplicate)

df_developers = pd.DataFrame(developers)
df_developers = apply_format_errors(df_developers, "name")
df_developers = apply_format_errors(df_developers, "specialty")

# %%
# --- TABLE BUG ---
bug_titles = [
    "Login button not responding on mobile",
    "Database connection timeout after 30 seconds",
    "User profile image not uploading",
    "Password reset email not sent",
    "Dashboard loads slowly with large datasets",
]
bug_descriptions = [
    "Steps to reproduce: 1. Navigate to login page 2. Click login button 3. Nothing happens",
    "The application loses connection to the database after exactly 30 seconds of inactivity",
    "When users try to upload a profile picture, the upload progress bar reaches 100% but image never appears",
]
severity_options = ["Low", "Medium", "High", "Critical"]
status_options = ["Open", "In Progress", "Fixed", "Closed"]

bugs = []
for bugid in range(70):
    project_index = rnd.randint(0, len(df_projects)-1)
    title = rnd.choice(bug_titles)
    bugs.append({
        "bugid": bugid + 1,
        "student_fullname": student_fullname,
        "projectid": project_index + 1,
        "title": title,
        "description": rnd.choice(bug_descriptions),
        "severity": rnd.choice(severity_options),
        "status": rnd.choice(status_options),
        "createdby": fake.name()
    })

original_indices = rnd.sample(range(70), 30)
for i in original_indices:
    duplicate = bugs[i].copy()
    bugs.append(duplicate)

df_bugs = pd.DataFrame(bugs)
df_bugs = apply_format_errors(df_bugs, "title")
df_bugs = apply_format_errors(df_bugs, "severity")

# %%
# --- TABLE RELEASES ---
release_notes = [
    "Fixed critical security vulnerability",
    "Added new dashboard with real-time analytics",
    "Improved performance by 40%",
]
releases = []
for releaseid in range(60):
    project_index = rnd.randint(0, len(df_projects)-1)
    version = f"{rnd.randint(0,5)}.{rnd.randint(0,9)}.{rnd.randint(0,9)}"
    release_date = df_projects.iloc[project_index]["startdate"] + timedelta(days=rnd.randint(0,365))
    releases.append({
        "releaseid": releaseid, 
        "student_fullname": student_fullname,
        "projectid": project_index + 1,
        "version": version,
        "releasedate": release_date,
        "notes": rnd.choice(release_notes)
    })

original_indices = rnd.sample(range(60), 20)
for i in original_indices:
    duplicate = releases[i].copy()
    releases.append(duplicate)

df_releases = pd.DataFrame(releases)
df_releases = apply_format_errors(df_releases, "version")
df_releases = apply_format_errors(df_releases, "notes")

# %%
# --- TABLE BUGFIX ---
fix_descriptions = [
    "Updated authentication logic",
    "Optimized database query",
    "Fixed file upload handler",
]
bugfixes = []
for fixid in range(90):
    bug_index = rnd.randint(0, len(df_bugs)-1)
    dev_index = rnd.randint(0, len(df_developers)-1)
    bugfixes.append({
        "fixid": fixid + 1, 
        "student_fullname": student_fullname,
        "bugid": bug_index + 1,
        "devid": dev_index + 1,
        "fixdate": pd.Timestamp.now().date(),
        "description": rnd.choice(fix_descriptions)
    })

original_indices = rnd.sample(range(90), 30)
for i in original_indices:
    duplicate = bugfixes[i].copy()
    bugfixes.append(duplicate)

df_bugfix = pd.DataFrame(bugfixes)
df_bugfix = apply_format_errors(df_bugfix, "description")

# %%
# --- TABLE PROJECTDEVELOPER ---
project_developers = []
for _ in range(60):
    proj_index = rnd.randint(0, len(df_projects)-1)
    dev_index = rnd.randint(0, len(df_developers)-1)
    pd_entry = {
        "projectid": proj_index + 1,
        "devid": dev_index + 1,
        "student_fullname": student_fullname
    }
    project_developers.append(pd_entry)

df_projectdeveloper = pd.DataFrame(project_developers)
df_projectdeveloper = apply_format_errors(df_projectdeveloper, "student_fullname")

# %%
df_projects.to_csv("export_csv/projects.csv", index=False)
df_developers.to_csv("export_csv/developers.csv", index=False)
df_bugs.to_csv("export_csv/bugs.csv", index=False)
df_releases.to_csv("export_csv/releases.csv", index=False)
df_bugfix.to_csv("export_csv/bugfixes.csv", index=False)
df_projectdeveloper.to_csv("export_csv/project_developers.csv", index=False)
