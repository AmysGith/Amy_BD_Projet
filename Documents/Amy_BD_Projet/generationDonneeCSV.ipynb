# %%
from faker import Faker
import pandas as pd 
import random as rnd 
from datetime import datetime, timedelta
import shutil

# %%
# --- Configuration ---
Faker.seed(42)
fake = Faker()

# %%
student_fullname = "RATSIHOARANA Nomenahitantsoa Amy Andriamalala"

# %%
# --- Fonction erreurs de formatage ---
def apply_format_errors(df, col):
    for i in df.index:
        r = rnd.random()
        val = str(df.at[i, col])
        if r < 0.3:       # 30 % majuscules + espaces
            df.at[i, col] = "  " + val.upper() + "  "
        elif r < 0.5:     # 20 % minuscules
            df.at[i, col] = val.lower()
        # 50 % reste inchangé
    return df

# %%
projects = []
for pid in range(1, 41):  # 40 projets uniques
    start_date = fake.date_between(start_date='-2y', end_date='-1y')
    end_date = fake.date_between(start_date=start_date, end_date='today')
    
    projects.append({
        "projectid": pid,
        "student_fullname": student_fullname,
        "name": fake.catch_phrase(),                 # cohérent + réaliste
        "client": fake.company(),
        "startdate": start_date,
        "enddate": end_date,
        "version": f"{rnd.randint(0,5)}.{rnd.randint(0,9)}.{rnd.randint(0,9)}"
    })

# Ajout de 20 doublons : même données sauf ID
indices = rnd.sample(range(40), 20)
for i in indices:
    dup = projects[i].copy()
    dup["projectid"] = len(projects) + 1
    projects.append(dup)

df_projects = pd.DataFrame(projects)
df_projects = apply_format_errors(df_projects, "name")
df_projects = apply_format_errors(df_projects, "client")

print(df_projects)
# Out:
#     projectid                               student_fullname  \
# 0           1  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 1           2  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 2           3  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 3           4  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 4           5  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 5           6  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 6           7  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 7           8  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 8           9  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 9          10  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 10         11  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 11         12  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 12         13  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 13         14  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 14         15  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 15         16  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 16         17  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 17         18  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 18         19  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 19         20  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 20         21  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 21         22  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 22         23  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 23         24  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 24         25  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 25         26  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 26         27  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 27         28  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 28         29  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 29         30  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 30         31  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 31         32  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 32         33  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 33         34  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 34         35  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 35         36  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 36         37  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 37         38  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 38         39  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 39         40  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 40         41  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 41         42  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 42         43  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 43         44  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 44         45  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 45         46  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 46         47  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 47         48  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 48         49  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 49         50  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 50         51  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 51         52  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 52         53  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 53         54  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 54         55  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 55         56  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 56         57  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 57         58  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 58         59  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 59         60  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
#
#                                                  name  \
# 0                      User-centric needs-based array
# 1        Assimilated next generation customer loyalty
# 2                   Adaptive well-modulated workforce
# 3    Extended well-modulated Graphical User Interface
# 4                         Robust empowering workforce
# 5                          Configurable neutral frame
# 6                         BALANCED STABLE EMULATION
# 7            MULTI-TIERED EVEN-KEELED KNOWLEDGEBASE
# 8                              Total systemic project
# 9                    Diverse maximized implementation
# 10               Synergized fresh-thinking throughput
# 11         Open-architected encompassing architecture
# 12             Extended solution-oriented methodology
# 13                           devolved dynamic synergy
# 14                Multi-lateral directional challenge
# 15                       DIVERSE SYSTEMIC INTERFACE
# 16                             Reactive 24/7 software
# 17            Customizable explicit Internet solution
# 18       Profit-focused well-modulated conglomeration
# 19                     Robust dedicated collaboration
# 20                 Adaptive radical Graphic Interface
# 21                    FRONT-LINE ANALYZING ENCODING
# 22            Public-key zero administration capacity
# 23                    Progressive real-time interface
# 24                Universal fault-tolerant initiative
# 25   Face-to-face asymmetric Graphical User Interface
# 26                   ADAPTIVE ASYNCHRONOUS STRATEGY
# 27             PROFOUND DISINTERMEDIATE FOCUS GROUP
# 28       FULLY-CONFIGURABLE ZERO TOLERANCE LEVERAGE
# 29           Optimized incremental Local Area Network
# 30                          upgradable global website
# 31                 DEVOLVED INTERACTIVE CONTINGENCY
# 32         REACTIVE BANDWIDTH-MONITORED APPLICATION
# 33                  Front-line composite installation
# 34                   DOWN-SIZED HOMOGENEOUS ABILITY
# 35                  optimized tangible superstructure
# 36                     reduced user-facing moratorium
# 37                     Polarized motivating moderator
# 38                  Enterprise-wide asymmetric policy
# 39                 Re-contextualized dynamic paradigm
# 40                 Re-contextualized dynamic paradigm
# 41             Multi-tiered even-keeled knowledgebase
# 42     ASSIMILATED NEXT GENERATION CUSTOMER LOYALTY
# 43                   POLARIZED MOTIVATING MODERATOR
# 44                          Upgradable global website
# 45   Face-to-face asymmetric Graphical User Interface
# 46                         configurable neutral frame
# 47           optimized incremental local area network
# 48         Fully-configurable zero tolerance leverage
# 49                     Reduced user-facing moratorium
# 50                       DIVERSE SYSTEMIC INTERFACE
# 51       OPEN-ARCHITECTED ENCOMPASSING ARCHITECTURE
# 52    EXTENDED WELL-MODULATED GRAPHICAL USER INTER...
# 53             extended solution-oriented methodology
# 54                   devolved interactive contingency
# 55                Multi-lateral directional challenge
# 56                          Balanced stable emulation
# 57               Synergized fresh-thinking throughput
# 58                           Devolved dynamic synergy
# 59                  enterprise-wide asymmetric policy
#
#                                client   startdate     enddate version
# 0     henderson, johnson and robinson  2024-01-20  2025-06-28   5.0.7
# 1        Santos, Gardner and Robinson  2024-06-25  2025-10-05   2.9.6
# 2                           Wolfe LLC  2024-07-27  2025-02-28   4.3.6
# 3                           davis inc  2024-03-28  2024-07-26   5.4.6
# 4                           Blair PLC  2024-04-29  2025-01-21   0.7.3
# 5         Montgomery, Hensley and Ray  2024-01-29  2024-11-18   1.9.9
# 6                    GALLOWAY-WYATT    2024-09-10  2024-11-03   2.8.7
# 7           Flowers, Martin and Kelly  2024-11-12  2025-01-29   4.7.8
# 8                      Lynch and Sons  2024-08-28  2025-03-23   0.5.3
# 9                         Mayo-Bowman  2024-07-06  2025-01-12   1.6.9
# 10                          Perez Inc  2024-07-15  2025-01-01   2.7.9
# 11                         gentry plc  2024-10-19  2025-06-21   0.9.1
# 12                    WILKERSON-DAY    2024-11-16  2025-07-18   1.3.8
# 13      RYAN, BURGESS AND PATTERSON    2024-02-05  2024-08-28   1.2.1
# 14      SNYDER, CAMPOS AND CALLAHAN    2024-07-25  2025-05-31   2.6.5
# 15         BROWN, JAMES AND FERRELL    2024-02-09  2025-06-10   5.9.9
# 16            wilson, dyer and potter  2024-07-04  2025-01-15   5.1.6
# 17                         Chavez Ltd  2024-10-05  2025-06-26   3.1.1
# 18          gaines, harrell and evans  2024-11-16  2025-06-08   4.6.3
# 19                        Farmer-Ryan  2024-08-16  2025-09-14   0.1.1
# 20                      smith-hickman  2024-10-09  2025-11-24   2.3.2
# 21        ARROYO, MILLER AND TUCKER    2024-11-17  2025-07-13   5.9.0
# 22                         Keller PLC  2024-01-07  2025-08-19   0.5.4
# 23                        hickman ltd  2024-02-14  2024-09-06   1.9.7
# 24           SANTOS, KIM AND HOLMES    2024-09-04  2025-02-07   4.7.7
# 25                   Chapman and Sons  2024-01-27  2024-08-06   3.9.0
# 26           brown, jones and johnson  2024-07-27  2025-01-14   4.0.6
# 27      washington, ryan and cummings  2024-04-18  2024-06-12   0.2.0
# 28                          Lee-Davis  2024-11-18  2025-11-20   3.6.8
# 29            brown, valdez and lucas  2024-05-27  2025-02-26   1.2.3
# 30                    Wright and Sons  2024-01-04  2024-11-11   1.5.9
# 31                      FORD-BAXTER    2024-07-07  2025-06-20   2.5.3
# 32               Kidd, Huff and Novak  2024-01-10  2024-12-19   5.0.2
# 33                    OLSON-HANCOCK    2024-12-05  2025-09-23   4.2.0
# 34                       baker-bowers  2024-11-26  2024-12-18   0.3.2
# 35          STANLEY, TUCKER AND LEE    2024-06-05  2025-01-12   5.6.5
# 36                       ADKINS INC    2024-03-05  2024-04-19   2.6.9
# 37                          Brown PLC  2023-12-31  2025-03-28   3.1.1
# 38                   Leonard and Sons  2024-01-12  2025-11-03   3.0.7
# 39    WILLIAMS, MILLER AND SANDOVAL    2024-05-16  2024-08-17   2.4.3
# 40      Williams, Miller and Sandoval  2024-05-16  2024-08-17   2.4.3
# 41          Flowers, Martin and Kelly  2024-11-12  2025-01-29   4.7.8
# 42       Santos, Gardner and Robinson  2024-06-25  2025-10-05   2.9.6
# 43                        BROWN PLC    2023-12-31  2025-03-28   3.1.1
# 44                  WRIGHT AND SONS    2024-01-04  2024-11-11   1.5.9
# 45                 CHAPMAN AND SONS    2024-01-27  2024-08-06   3.9.0
# 46        Montgomery, Hensley and Ray  2024-01-29  2024-11-18   1.9.9
# 47            Brown, Valdez and Lucas  2024-05-27  2025-02-26   1.2.3
# 48                          Lee-Davis  2024-11-18  2025-11-20   3.6.8
# 49                         Adkins Inc  2024-03-05  2024-04-19   2.6.9
# 50           Brown, James and Ferrell  2024-02-09  2025-06-10   5.9.9
# 51                         gentry plc  2024-10-19  2025-06-21   0.9.1
# 52                          Davis Inc  2024-03-28  2024-07-26   5.4.6
# 53                      Wilkerson-Day  2024-11-16  2025-07-18   1.3.8
# 54                        Ford-Baxter  2024-07-07  2025-06-20   2.5.3
# 55        Snyder, Campos and Callahan  2024-07-25  2025-05-31   2.6.5
# 56                   GALLOWAY-WYATT    2024-09-10  2024-11-03   2.8.7
# 57                          Perez Inc  2024-07-15  2025-01-01   2.7.9
# 58        ryan, burgess and patterson  2024-02-05  2024-08-28   1.2.1
# 59                   Leonard and Sons  2024-01-12  2025-11-03   3.0.7

# %%
# --- TABLE DEVELOPER ---
developers = []

for did in range(1, 41):  # 40 développeurs uniques
    name = fake.name()
    email = fake.email()  # email réaliste
    
    developers.append({
        "devid": did,
        "student_fullname": student_fullname,
        "name": name,
        "email": email,
        "specialty": fake.job(),   # métier cohérent
    })

# 20 doublons (mêmes données sauf ID)
indices = rnd.sample(range(40), 20)
for i in indices:
    dup = developers[i].copy()
    dup["devid"] = len(developers) + 1   # nouveau ID
    developers.append(dup)

df_developers = pd.DataFrame(developers)
df_developers = apply_format_errors(df_developers, "name")
df_developers = apply_format_errors(df_developers, "specialty")

# %%
severity_options = ["Low", "Medium", "High", "Critical"]
status_options = ["Open", "In Progress", "Fixed", "Closed"]

bugs = []

for bid in range(1, 71):  # 70 bugs uniques
    proj = rnd.choice(projects)  # un vrai projet existant
    
    bugs.append({
        "bugid": bid,
        "student_fullname": student_fullname,
        "projectid": proj["projectid"],     # cohérent
        "title": fake.sentence(nb_words=6), # titre cohérent
        "description": fake.paragraph(nb_sentences=3),
        "severity": rnd.choice(severity_options),
        "status": rnd.choice(status_options),
        "createdby": fake.name(),
    })

# 30 doublons (mêmes données sauf ID)
indices = rnd.sample(range(70), 30)
for i in indices:
    dup = bugs[i].copy()
    dup["bugid"] = len(bugs) + 1
    bugs.append(dup)

df_bugs = pd.DataFrame(bugs)
df_bugs = apply_format_errors(df_bugs, "title")
df_bugs = apply_format_errors(df_bugs, "severity")

# %%
releases = []

for releaseid in range(60):
    proj = rnd.choice(df_projects.to_dict(orient='records'))
    version = f"{fake.random_int(0,5)}.{fake.random_int(0,9)}.{fake.random_int(0,9)}"
    release_date = proj["startdate"] + timedelta(days=rnd.randint(0, 365))
    notes = fake.sentence(nb_words=8)

    releases.append({
        "releaseid": releaseid + 1,
        "student_fullname": student_fullname,
        "projectid": proj["projectid"],
        "version": version,
        "releasedate": release_date,
        "notes": notes
    })

original_indices = rnd.sample(range(60), 20)
for i in original_indices:
    duplicate = releases[i].copy()
    duplicate["releaseid"] = len(releases) + 1
    releases.append(duplicate)

df_releases = pd.DataFrame(releases)
df_releases = apply_format_errors(df_releases, "version")
df_releases = apply_format_errors(df_releases, "notes")

# %%
# --- TABLE BUGFIX ---
bugfixes = []

for fixid in range(90):
    bug = rnd.choice(df_bugs.to_dict(orient='records'))
    dev = rnd.choice(df_developers.to_dict(orient='records'))

    bugfixes.append({
        "fixid": fixid + 1,
        "student_fullname": student_fullname,
        "bugid": bug["bugid"],
        "devid": dev["devid"],
        "fixdate": fake.date_between(start_date="-1y", end_date="today"),
        "description": fake.sentence(nb_words=8)
    })

original_indices = rnd.sample(range(90), 30)
for i in original_indices:
    duplicate = bugfixes[i].copy()
    duplicate["fixid"] = len(bugfixes) + 1
    bugfixes.append(duplicate)

df_bugfix = pd.DataFrame(bugfixes)
df_bugfix = apply_format_errors(df_bugfix, "description")

# %%
# --- TABLE PROJECTDEVELOPER ---
projectdevelopers = []

for _ in range(60):
    proj = rnd.choice(df_projects.to_dict(orient='records'))
    dev = rnd.choice(df_developers.to_dict(orient='records'))

    projectdevelopers.append({
        "projectid": proj["projectid"],
        "devid": dev["devid"],
        "student_fullname": student_fullname
    })

df_projectdeveloper = pd.DataFrame(projectdevelopers)
df_projectdeveloper = apply_format_errors(df_projectdeveloper, "student_fullname")

# %%
df_projects.to_csv("export_csv/projects.csv", index=False)
df_developers.to_csv("export_csv/developers.csv", index=False)
df_bugs.to_csv("export_csv/bugs.csv", index=False)
df_releases.to_csv("export_csv/releases.csv", index=False)
df_bugfix.to_csv("export_csv/bugfixes.csv", index=False)
df_projectdeveloper.to_csv("export_csv/project_developers.csv", index=False)

# %%
df_projectdeveloper.to_csv("export_csv/project_developers.csv", index=False)
