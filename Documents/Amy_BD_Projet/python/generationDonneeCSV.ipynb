# %%
from faker import Faker
import pandas as pd 
import random as rnd 
from datetime import datetime, timedelta
import shutil

# %%
# --- Configuration ---
Faker.seed(42)
fake = Faker()

# %%
student_fullname = "RATSIHOARANA Nomenahitantsoa Amy Andriamalala"

# %%
def apply_format_errors(df, col, is_email=False, error_rate=0.3):
    """
    Applique des erreurs de format sur une colonne d'un DataFrame.
    
    Paramètres :
    - df : DataFrame pandas
    - col : nom de la colonne à modifier
    - is_email : True si c'est une colonne email (ajoute des erreurs spécifiques)
    - error_rate : proportion d'erreurs à appliquer systématiquement (0 à 1)
    """
    for i in df.index:
        val = str(df.at[i, col])
        
        # Appliquer des erreurs sur toutes les lignes selon error_rate
        if rnd.random() < error_rate:
            # Cas général : maj/min/mix
            r = rnd.random()
            if r < 0.33:
                val = val.upper()
            elif r < 0.66:
                val = val.lower()
            else:
                val = "".join(rnd.choice([c.upper(), c.lower()]) for c in val)
            
            # Si colonne email, ajouter des erreurs aléatoires
            if is_email:
                err = rnd.random()
                if err < 0.1:          # 10 % enlever @
                    val = val.replace("@", "")
                elif err < 0.2:        # 10 % enlever .
                    val = val.replace(".", "")
                elif err < 0.25:       # 5 % ajouter un espace
                    val = val.replace("@", " @")
                elif err < 0.3:        # 5 % remplacer un caractère aléatoire par un chiffre
                    if len(val) > 3:
                        pos = rnd.randint(0, len(val)-1)
                        val = val[:pos] + str(rnd.randint(0,9)) + val[pos+1:]
                elif err < 0.35:       # 5 % rendre email nul
                    val = None
        
        df.at[i, col] = val
    
    return df

# %%
projects = []
for pid in range(1, 41):  # 40 projets uniques
    start_date = fake.date_between(start_date='-2y', end_date='-1y')
    end_date = fake.date_between(start_date=start_date, end_date='today')
    
    projects.append({
        "projectid": pid,
        "student_fullname": student_fullname,
        "name": fake.catch_phrase(),                
        "client": fake.company(),
        "startdate": start_date,
        "enddate": end_date,
        "version": f"{rnd.randint(0,5)}.{rnd.randint(0,9)}.{rnd.randint(0,9)}"
    })

# Ajout de 20 doublons : même données sauf ID
indices = rnd.sample(range(40), 20)
for i in indices:
    dup = projects[i].copy()
    dup["projectid"] = len(projects) + 1
    projects.append(dup)

df_projects = pd.DataFrame(projects)
df_projects = apply_format_errors(df_projects, "name")
df_projects = apply_format_errors(df_projects, "client")
df_projects = apply_format_errors(df_projects, "student_fullname")
print(df_projects)
# Out:
#     projectid                               student_fullname  \
# 0           1  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 1           2  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 2           3  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 3           4  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 4           5  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 5           6  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 6           7  ratsihoarana nomenahitantsoa amy andriamalala
# 7           8  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 8           9  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 9          10  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 10         11  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 11         12  RaTSIhOaraNa nomenaHitantsoA aMY aNDriaMaLALA
# 12         13  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 13         14  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 14         15  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 15         16  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 16         17  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 17         18  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 18         19  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 19         20  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 20         21  RatsIhOarAna nomenaHiTAnTsoa amY aNdriAMaLAla
# 21         22  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 22         23  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 23         24  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 24         25  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 25         26  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 26         27  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 27         28  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 28         29  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 29         30  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 30         31  ratsihoarana nomenahitantsoa amy andriamalala
# 31         32  ratsihoarana nomenahitantsoa amy andriamalala
# 32         33  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 33         34  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 34         35  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 35         36  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 36         37  ratsihoarana nomenahitantsoa amy andriamalala
# 37         38  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 38         39  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 39         40  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 40         41  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 41         42  RaTSIhOarAna nomeNahItanTsoA amy aNdrIAMaLALA
# 42         43  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 43         44  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 44         45  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 45         46  ratsihoarana nomenahitantsoa amy andriamalala
# 46         47  ratsiHoaRANa nomeNahItaNTSOA AmY aNDRIAmALALa
# 47         48  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 48         49  rATSiHOARaNA NOMENahITANtsoa amy anDrIamAlAlA
# 49         50  rATsihoaRana NOmeNaHITaNTsOa amY aNdrIamalaLa
# 50         51  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 51         52  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 52         53  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 53         54  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 54         55  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 55         56  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 56         57  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 57         58  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
# 58         59  RATSIHOARANA NOMENAHITANTSOA AMY ANDRIAMALALA
# 59         60  RATSIHOARANA Nomenahitantsoa Amy Andriamalala
#
#                                                 name  \
# 0                Assimilated user-facing focus group
# 1                     UseR-cENTrIC NEEds-bASeD ARRAY
# 2       assimilated next generation customer loyalty
# 3                  Adaptive well-modulated workforce
# 4   Extended well-modulated Graphical User Interface
# 5                        Robust empowering workforce
# 6                         configurable neutral frame
# 7                          Balanced stable emulation
# 8             Multi-tiered even-keeled knowledgebase
# 9                             TOTAL SYSTEMIC PROJECT
# 10                  Diverse maximized implementation
# 11              Synergized fresh-thinking throughput
# 12        Open-architected encompassing architecture
# 13            Extended solution-oriented methodology
# 14                          devolved dynamic synergy
# 15               MULTI-LATERAL DIRECTIONAL CHALLENGE
# 16                        Diverse systemic interface
# 17                            Reactive 24/7 software
# 18           Customizable explicit Internet solution
# 19      ProFit-fOCusED wElL-MOdulaTEd COnglOmERATiOn
# 20                    Robust dedicated collaboration
# 21                Adaptive radical Graphic Interface
# 22                     FRONT-LINE ANALYZING ENCODING
# 23           Public-key zero administration capacity
# 24                   Progressive real-time interface
# 25               UNIVERSAL FAULT-TOLERANT INITIATIVE
# 26  Face-to-face asymmetric Graphical User Interface
# 27                    Adaptive asynchronous strategy
# 28              PROFOUND DISINTERMEDIATE FOCUS GROUP
# 29        fully-configurable zero tolerance leverage
# 30          optimized incremental local area network
# 31                         upgradable global website
# 32                  Devolved interactive contingency
# 33          Reactive bandwidth-monitored application
# 34                 Front-line composite installation
# 35                    Down-sized homogeneous ability
# 36                 Optimized tangible superstructure
# 37                    Reduced user-facing moratorium
# 38                    Polarized motivating moderator
# 39                 Enterprise-wide asymmetric policy
# 40              Profound disintermediate focus group
# 41               Assimilated user-facing focus group
# 42                    Reduced user-facing moratorium
# 43                    ROBUST DEDICATED COLLABORATION
# 44               Multi-lateral directional challenge
# 45          Reactive bandwidth-monitored application
# 46                Adaptive radical Graphic Interface
# 47                 ADAPTIVE WELL-MODULATED WORKFORCE
# 48                  Diverse maximized implementation
# 49                    down-sized homogeneous ability
# 50                   Progressive real-time interface
# 51                  Devolved interactive contingency
# 52      Profit-focused well-modulated conglomeration
# 53                            Total systemic project
# 54        fully-configurable zero tolerance leverage
# 55           Public-key zero administration capacity
# 56                        Configurable neutral frame
# 57               Universal fault-tolerant initiative
# 58                         Upgradable global website
# 59                    Adaptive asynchronous strategy
#
#                              client   startdate     enddate version
# 0                        waLkER LTd  2024-08-17  2024-11-11   2.3.6
# 1   hEndeRSoN, JoHNsOn aNd rOBINsON  2024-01-21  2025-06-29   2.7.7
# 2      SANtOs, GArDNeR AND RObiNsOn  2024-06-26  2025-10-06   4.4.2
# 3                         Wolfe LLC  2024-07-28  2025-03-01   3.5.4
# 4                         DAVIS INC  2024-03-29  2024-07-27   5.8.9
# 5                         Blair PLC  2024-04-30  2025-01-22   2.8.5
# 6       MONTGOMERY, HENSLEY AND RAY  2024-01-30  2024-11-19   1.5.1
# 7                    gaLLOWAY-wyaTt  2024-09-11  2024-11-04   2.5.0
# 8         flOweRS, MaRTiN aND KElLy  2024-11-13  2025-01-30   5.3.3
# 9                    Lynch and Sons  2024-08-29  2025-03-24   0.0.0
# 10                      Mayo-Bowman  2024-07-07  2025-01-13   5.7.0
# 11                        perez inc  2024-07-16  2025-01-02   1.5.1
# 12                       Gentry PLC  2024-10-20  2025-06-22   5.1.9
# 13                    Wilkerson-Day  2024-11-17  2025-07-19   1.8.1
# 14      Ryan, Burgess and Patterson  2024-02-06  2024-08-29   2.1.5
# 15      Snyder, Campos and Callahan  2024-07-26  2025-06-01   2.9.6
# 16         brown, james and ferrell  2024-02-10  2025-06-11   2.0.1
# 17          Wilson, Dyer and Potter  2024-07-05  2025-01-16   2.1.6
# 18                       chavez ltd  2024-10-06  2025-06-27   4.1.9
# 19        Gaines, Harrell and Evans  2024-11-17  2025-06-09   1.7.9
# 20                      farmer-ryaN  2024-08-17  2025-09-15   4.5.9
# 21                    SMITH-HICKMAN  2024-10-10  2025-11-25   0.5.7
# 22        Arroyo, Miller and Tucker  2024-11-18  2025-07-14   4.8.7
# 23                       Keller PLC  2024-01-08  2025-08-20   1.0.1
# 24                      Hickman Ltd  2024-02-15  2024-09-07   5.6.9
# 25           Santos, Kim and Holmes  2024-09-05  2025-02-08   5.5.4
# 26                 CHAPMAN AND SONS  2024-01-28  2024-08-07   0.5.4
# 27         Brown, Jones and Johnson  2024-07-28  2025-01-15   5.7.5
# 28    Washington, Ryan and Cummings  2024-04-19  2024-06-13   5.4.7
# 29                        lee-davis  2024-11-19  2025-11-21   5.3.5
# 30          brown, valdez and lucas  2024-05-28  2025-02-27   5.4.3
# 31                  Wright and Sons  2024-01-05  2024-11-12   2.1.3
# 32                      Ford-Baxter  2024-07-08  2025-06-21   0.3.6
# 33             Kidd, Huff and Novak  2024-01-11  2024-12-20   2.8.1
# 34                    Olson-Hancock  2024-12-06  2025-09-24   3.6.8
# 35                     Baker-Bowers  2024-11-27  2024-12-19   0.6.0
# 36          stANlEY, tUCkeR AND LEe  2024-06-06  2025-01-13   3.1.6
# 37                       adkins inc  2024-03-06  2024-04-20   1.7.5
# 38                        Brown PLC  2024-01-01  2025-03-29   3.4.6
# 39                 Leonard and Sons  2024-01-13  2025-11-04   0.7.4
# 40    washington, ryan and cummings  2024-04-19  2024-06-13   5.4.7
# 41                       Walker Ltd  2024-08-17  2024-11-11   2.3.6
# 42                       ADKINS INC  2024-03-06  2024-04-20   1.7.5
# 43                      Farmer-Ryan  2024-08-17  2025-09-15   4.5.9
# 44      Snyder, Campos and Callahan  2024-07-26  2025-06-01   2.9.6
# 45             Kidd, Huff and Novak  2024-01-11  2024-12-20   2.8.1
# 46                    Smith-Hickman  2024-10-10  2025-11-25   0.5.7
# 47                        wolfe llc  2024-07-28  2025-03-01   3.5.4
# 48                      mAyo-BOWMAN  2024-07-07  2025-01-13   5.7.0
# 49                     Baker-Bowers  2024-11-27  2024-12-19   0.6.0
# 50                      HICKMAN LTD  2024-02-15  2024-09-07   5.6.9
# 51                      Ford-Baxter  2024-07-08  2025-06-21   0.3.6
# 52        Gaines, Harrell and Evans  2024-11-17  2025-06-09   1.7.9
# 53                   lynch and sons  2024-08-29  2025-03-24   0.0.0
# 54                        Lee-Davis  2024-11-19  2025-11-21   5.3.5
# 55                       kElLer PLC  2024-01-08  2025-08-20   1.0.1
# 56      Montgomery, Hensley and Ray  2024-01-30  2024-11-19   1.5.1
# 57           Santos, Kim and Holmes  2024-09-05  2025-02-08   5.5.4
# 58                  WRIGHT AND SONS  2024-01-05  2024-11-12   2.1.3
# 59         Brown, Jones and Johnson  2024-07-28  2025-01-15   5.7.5

# %%
developers = []

# 40 développeurs uniques
for did in range(1, 41):
    name = fake.name()  # généré ailleurs
    email_clean = name.replace(" ", ".").lower() + "@gmail.com"
    
    developers.append({
        "devid": did,
        "student_fullname": student_fullname,
        "name": name,
        "email": email_clean,
        "specialty": fake.job(),
    })

# 20 doublons
indices = rnd.sample(range(40), 20)
for i in indices:
    dup = developers[i].copy()
    dup["devid"] = len(developers) + 1
    developers.append(dup)

df_developers = pd.DataFrame(developers)

# Appliquer erreurs
df_developers = apply_format_errors(df_developers, "name")
df_developers = apply_format_errors(df_developers, "specialty")
df_developers = apply_format_errors(df_developers, "email", is_email=True, error_rate=1.0)
df_developers = apply_format_errors(df_developers, "student_fullname")

# %%
severity_options = ["Low", "Medium", "High", "Critical"]
status_options = ["Open", "In Progress", "Fixed", "Closed"]

bugs = []

for bid in range(1, 71):  # 70 bugs uniques
    proj = rnd.choice(projects)  # un vrai projet existant
    
    bugs.append({
        "bugid": bid,
        "student_fullname": student_fullname,
        "projectid": proj["projectid"],     # cohérent
        "title": fake.sentence(nb_words=6), # titre cohérent
        "description": fake.paragraph(nb_sentences=3),
        "severity": rnd.choice(severity_options),
        "status": rnd.choice(status_options),
        "createdby": fake.name(),
    })

# 30 doublons (mêmes données sauf ID)
indices = rnd.sample(range(70), 30)
for i in indices:
    dup = bugs[i].copy()
    dup["bugid"] = len(bugs) + 1
    bugs.append(dup)

df_bugs = pd.DataFrame(bugs)
df_bugs = apply_format_errors(df_bugs, "title")
df_bugs = apply_format_errors(df_bugs, "severity")
df_bugs = apply_format_errors(df_bugs, "student_fullname")

# %%
releases = []

for releaseid in range(60):
    proj = rnd.choice(df_projects.to_dict(orient='records'))
    version = f"{fake.random_int(0,5)}.{fake.random_int(0,9)}.{fake.random_int(0,9)}"
    release_date = proj["startdate"] + timedelta(days=rnd.randint(0, 365))
    notes = fake.sentence(nb_words=8)

    releases.append({
        "releaseid": releaseid + 1,
        "student_fullname": student_fullname,
        "projectid": proj["projectid"],
        "version": version,
        "releasedate": release_date,
        "notes": notes
    })

original_indices = rnd.sample(range(60), 20)
for i in original_indices:
    duplicate = releases[i].copy()
    duplicate["releaseid"] = len(releases) + 1
    releases.append(duplicate)

df_releases = pd.DataFrame(releases)
df_releases = apply_format_errors(df_releases, "version")
df_releases = apply_format_errors(df_releases, "notes")
df_releases = apply_format_errors(df_releases, "student_fullname")

# %%
# --- TABLE BUGFIX ---
bugfixes = []

for fixid in range(90):
    bug = rnd.choice(df_bugs.to_dict(orient='records'))
    dev = rnd.choice(df_developers.to_dict(orient='records'))

    bugfixes.append({
        "fixid": fixid + 1,
        "student_fullname": student_fullname,
        "bugid": bug["bugid"],
        "devid": dev["devid"],
        "fixdate": fake.date_between(start_date="-1y", end_date="today"),
        "description": fake.sentence(nb_words=8)
    })

original_indices = rnd.sample(range(90), 30)
for i in original_indices:
    duplicate = bugfixes[i].copy()
    duplicate["fixid"] = len(bugfixes) + 1
    bugfixes.append(duplicate)

df_bugfix = pd.DataFrame(bugfixes)
df_bugfix = apply_format_errors(df_bugfix, "description")
df_bugfix = apply_format_errors(df_bugfix, "student_fullname")

# %%
# --- TABLE PROJECTDEVELOPER ---
from itertools import product
import random

# toutes les combinaisons possibles projet x développeur
all_combinations = list(product(df_projects["projectid"], df_developers["devid"]))

# mélanger les combinaisons
random.shuffle(all_combinations)

# choisir 60 combinaisons uniques
chosen_combinations = all_combinations[:60]

projectdevelopers = []
for projid, devid in chosen_combinations:
    projectdevelopers.append({
        "projectid": projid,
        "devid": devid,
        "student_fullname": student_fullname
    })

df_projectdeveloper = pd.DataFrame(projectdevelopers)
df_projectdeveloper = apply_format_errors(df_projectdeveloper, "student_fullname")

# %%
import os

output_dir = "../export_csv"
os.makedirs(output_dir, exist_ok=True)

df_projects.to_csv(os.path.join(output_dir, "projects.csv"), index=False)
df_developers.to_csv(os.path.join(output_dir, "developers.csv"), index=False)
df_bugs.to_csv(os.path.join(output_dir, "bugs.csv"), index=False)
df_releases.to_csv(os.path.join(output_dir, "releases.csv"), index=False)
df_bugfix.to_csv(os.path.join(output_dir, "bugfixes.csv"), index=False)
df_projectdeveloper.to_csv(os.path.join(output_dir, "project_developers.csv"), index=False)
